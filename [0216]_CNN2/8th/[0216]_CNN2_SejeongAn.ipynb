# %% [markdown]
# # 초기 세팅

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms

import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

# %%
# !pip install torchsummary
from torchsummary import summary
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.8/dist-packages (1.5.1)

# %% [markdown]
# - 현재 GPU 설정

# %%
# colab의 runtime-type을 GPU로 설정해서, True가 나오도록 한다.

torch.cuda.is_available()
# Out:
# True

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') # gpu('cuda')가 사용가능하면, gpu를 이용하도록 설정
device
# Out:
# device(type='cuda')

# %% [markdown]
# # CIFAR10 분류 모델
# * R/G/B(3) 이미지 데이터 분류
# * 32x32 pixel

# %% [markdown]
# ## 전처리 설정

# %%
# transform 정의
CIFAR_transform = transforms.Compose([transforms.ToTensor(),
                                      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]) # r,g,b 데이터임으로, 3개의 인자값 전달

# %% [markdown]
# ## 데이터 로드 및 확인

# %%
# datasets

trainset = torchvision.datasets.CIFAR10(root='/content',
                                        train=True, download=True,
                                        transform=CIFAR_transform)

testset = torchvision.datasets.CIFAR10(root='/content',
                                       train=False, download=True,
                                       transform=CIFAR_transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# DataLoader

# batch-size = 4

train_loader = DataLoader(trainset, batch_size=128, shuffle=True, num_workers=2)

test_loader = DataLoader(testset, batch_size=128, shuffle=True, num_workers=2)

# %%
# 숫자 label에 해당되는 값

class_list = ('plane', 'car', 'bird', 'cat', 'deer',
              'dog', 'frog', 'horse', 'ship', 'truck')

# %%
def imshow(img):
    img = img / 2 + 0.5
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1,2,0)))
    plt.show()

dataiter = iter(train_loader)
images, labels = next(dataiter)

imshow(torchvision.utils.make_grid(images))
print(' '.join('{}\t'.format(class_list[labels[j]]) for j in range(4)))
# Out:
# car	 cat	 ship	 horse

# %% [markdown]
# ## 모델 생성

# %% [markdown]
# * input size = 4 * 3 * 32 * 32
# * output size = 4 * 10
# * 모델 조건
# > * convolution-layer : 2개 이상 사용
# > * maxpooling-layer : 1개 이상 사용
# > * fc-layer : 2개 이상 사용
# > * activation-function 으로 'relu' 사용

# %%
class Net(nn.Module):
    def __init__(self):
      super(Net, self).__init__()

      self.conv = nn.Sequential(
          nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1, stride=1), # [batch_size, 3, 32, 32] -> [batch_size, 32, 32, 32]
          nn.BatchNorm2d(32),
          nn.ReLU(inplace=True),
          nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1, stride=1), # [batch_size, 32, 32, 32] -> [batch_size, 32, 32, 32]
          nn.BatchNorm2d(32),
          nn.ReLU(inplace=True),
          nn.MaxPool2d(kernel_size=2, stride=2), # [batch_size, 32, 32, 32] -> [batch_size, 32, 16, 16]
            
          nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1, stride=1), # [batch_size, 32, 16, 16] -> [batch_size, 64, 16, 16]
          nn.BatchNorm2d(64),
          nn.ReLU(inplace=True),
          nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1, stride=1),
          nn.BatchNorm2d(64),
          nn.ReLU(inplace=True),
          nn.MaxPool2d(kernel_size=2, stride=2), # [batch_size, 64, 16, 16] -> [batch_size, 64, 8, 8]

          nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1, stride=1), # [batch_size, 64, 8, 8] -> [batch_size, 128, 8, 8]
          nn.BatchNorm2d(128),
          nn.ReLU(inplace=True),
          nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1, stride=1),
          nn.BatchNorm2d(128),
          nn.ReLU(inplace=True),
          nn.MaxPool2d(kernel_size=2, stride=2), # [batch_size, 128, 8, 8] -> [batch_size, 128, 4, 4]

          nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1, stride=1), # [batch_size, 64, 8, 8] -> [batch_size, 128, 8, 8]
          nn.BatchNorm2d(128),
          nn.ReLU(inplace=True),
          nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1, stride=1),
          nn.BatchNorm2d(128),
          nn.ReLU(inplace=True)
      )

      self.flat = nn.Flatten()

      self.fclayer = nn.Sequential(
          nn.Linear(128 * 4 * 4, 256),
          nn.ReLU(inplace=True),
          nn.Dropout(),
          nn.Linear(256, 256),
          nn.ReLU(inplace=True),
          nn.Dropout(),
          nn.Linear(256, 10)        
      )
    
    def forward(self, x):
      x = self.conv(x)
      x = self.flat(x)
      x = self.fclayer(x)
      return x

# %%
myNet = Net().to(device) # gpu에 모델 저장
myNet
# Out:
# Net(
#   (conv): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#     (17): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (21): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (23): ReLU(inplace=True)
#     (24): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU(inplace=True)
#   )
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (fclayer): Sequential(
#     (0): Linear(in_features=2048, out_features=256, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=256, out_features=256, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=256, out_features=10, bias=True)
#   )
# )

# %%
# input; (4 * 3 * 32 * 32)

input = images.to(device)
input.size()
# Out:
# torch.Size([128, 3, 32, 32])

# %%
# output; (4 * 10)

output = myNet.forward(input)
output.size()
# Out:
# torch.Size([128, 10])

# %%
# 모델 구조 확인

summary(myNet, input_size=(3, 32, 32), batch_size=64)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [64, 32, 32, 32]             896
#        BatchNorm2d-2           [64, 32, 32, 32]              64
#               ReLU-3           [64, 32, 32, 32]               0
#             Conv2d-4           [64, 32, 32, 32]           9,248
#        BatchNorm2d-5           [64, 32, 32, 32]              64
#               ReLU-6           [64, 32, 32, 32]               0
#          MaxPool2d-7           [64, 32, 16, 16]               0
#             Conv2d-8           [64, 64, 16, 16]          18,496
#        BatchNorm2d-9           [64, 64, 16, 16]             128
#              ReLU-10           [64, 64, 16, 16]               0
#            Conv2d-11           [64, 64, 16, 16]          36,928
#       BatchNorm2d-12           [64, 64, 16, 16]             128
#              ReLU-13           [64, 64, 16, 16]               0
#         MaxPool2d-14             [64, 64, 8, 8]               0
#            Conv2d-15            [64, 128, 8, 8]          73,856
#       BatchNorm2d-16            [64, 128, 8, 8]             256
#              ReLU-17            [64, 128, 8, 8]               0
#            Conv2d-18            [64, 128, 8, 8]         147,584
#       BatchNorm2d-19            [64, 128, 8, 8]             256
#              ReLU-20            [64, 128, 8, 8]               0
#         MaxPool2d-21            [64, 128, 4, 4]               0
#            Conv2d-22            [64, 128, 4, 4]         147,584
#       BatchNorm2d-23            [64, 128, 4, 4]             256
#              ReLU-24            [64, 128, 4, 4]               0
#            Conv2d-25            [64, 128, 4, 4]         147,584
#       BatchNorm2d-26            [64, 128, 4, 4]             256
#              ReLU-27            [64, 128, 4, 4]               0
#           Flatten-28                 [64, 2048]               0
#            Linear-29                  [64, 256]         524,544
#              ReLU-30                  [64, 256]               0
#           Dropout-31                  [64, 256]               0
#            Linear-32                  [64, 256]          65,792
#              ReLU-33                  [64, 256]               0
#           Dropout-34                  [64, 256]               0
#            Linear-35                   [64, 10]           2,570
# ================================================================
# Total params: 1,176,490
# Trainable params: 1,176,490
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 182.75
# Params size (MB): 4.49
# Estimated Total Size (MB): 187.99
# ----------------------------------------------------------------

# %% [markdown]
# ## 손실함수와 옵티마이저

# %%
criterion = nn.CrossEntropyLoss() # 다중분류; CrossEntropyLoss
optimizer = optim.NAdam(myNet.parameters(), lr=0.01) # SGD; lr=0.001 & momentum=0.9
lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=15, gamma=0.1)

# %% [markdown]
# ## 모델 학습

# %%
# epochs = 30

for epoch in range(30):
    running_loss = 0.0

    for i, data in enumerate(train_loader, 0):
        inputs, labels = data[0].to(device), data[1].to(device)

        optimizer.zero_grad()                 # 가중치 초기화

        outputs = myNet(inputs)               # y_pred
        loss = criterion(outputs, labels)     # 손실함수를 이용해서 loss계산
        loss.backward()                       # back-propagation
        optimizer.step()                      # 가중치 업데이트

        running_loss += loss.item()
        if i % 100 == 99:
            print("Epoch: {}, Batch: {}, Loss: {}".format(epoch+1, i+1, running_loss/2000))
            running_loss = 0.0
    lr_scheduler.step()
# Out:
# Epoch: 1, Batch: 100, Loss: 0.11743392515182495
# Epoch: 1, Batch: 200, Loss: 0.1053643900156021
# Epoch: 1, Batch: 300, Loss: 0.09757560378313064
# Epoch: 2, Batch: 100, Loss: 0.0897153446674347
# Epoch: 2, Batch: 200, Loss: 0.08349836891889573
# Epoch: 2, Batch: 300, Loss: 0.07939720571041108
# Epoch: 3, Batch: 100, Loss: 0.07182700341939927
# Epoch: 3, Batch: 200, Loss: 0.0691093715429306
# Epoch: 3, Batch: 300, Loss: 0.06502989584207534
# Epoch: 4, Batch: 100, Loss: 0.05847589614987373
# Epoch: 4, Batch: 200, Loss: 0.055580453515052794
# Epoch: 4, Batch: 300, Loss: 0.05354012155532837
# Epoch: 5, Batch: 100, Loss: 0.05043460807204247
# Epoch: 5, Batch: 200, Loss: 0.048339891493320464
# Epoch: 5, Batch: 300, Loss: 0.04663474151492119
# Epoch: 6, Batch: 100, Loss: 0.04283335614204407
# Epoch: 6, Batch: 200, Loss: 0.04282626935839653
# Epoch: 6, Batch: 300, Loss: 0.04194953918457031
# Epoch: 7, Batch: 100, Loss: 0.03920182880759239
# Epoch: 7, Batch: 200, Loss: 0.037942548304796216
# Epoch: 7, Batch: 300, Loss: 0.03810244923830032
# Epoch: 8, Batch: 100, Loss: 0.034817531436681745
# Epoch: 8, Batch: 200, Loss: 0.0348811666816473
# Epoch: 8, Batch: 300, Loss: 0.035367001131176946
# Epoch: 9, Batch: 100, Loss: 0.031741285040974614
# Epoch: 9, Batch: 200, Loss: 0.03101012608408928
# Epoch: 9, Batch: 300, Loss: 0.033497066274285316
# Epoch: 10, Batch: 100, Loss: 0.029884806349873543
# Epoch: 10, Batch: 200, Loss: 0.03015834665298462
# Epoch: 10, Batch: 300, Loss: 0.029954627081751825
# Epoch: 11, Batch: 100, Loss: 0.0273666233420372
# Epoch: 11, Batch: 200, Loss: 0.027942767538130284
# Epoch: 11, Batch: 300, Loss: 0.028050187915563584
# Epoch: 12, Batch: 100, Loss: 0.026481123939156533
# Epoch: 12, Batch: 200, Loss: 0.025934190481901168
# Epoch: 12, Batch: 300, Loss: 0.027209661602973938
# Epoch: 13, Batch: 100, Loss: 0.02414870324730873
# Epoch: 13, Batch: 200, Loss: 0.024380379900336265
# Epoch: 13, Batch: 300, Loss: 0.023944519534707068
# Epoch: 14, Batch: 100, Loss: 0.022572100199759006
# Epoch: 14, Batch: 200, Loss: 0.02263668330013752
# Epoch: 14, Batch: 300, Loss: 0.02340717253088951
# Epoch: 15, Batch: 100, Loss: 0.020765637136995793
# Epoch: 15, Batch: 200, Loss: 0.021313024669885636
# Epoch: 15, Batch: 300, Loss: 0.021883576802909373
# Epoch: 16, Batch: 100, Loss: 0.01715845961868763
# Epoch: 16, Batch: 200, Loss: 0.015580035641789437
# Epoch: 16, Batch: 300, Loss: 0.013946348197758198
# Epoch: 17, Batch: 100, Loss: 0.012280947204679251
# Epoch: 17, Batch: 200, Loss: 0.012217130202800035
# Epoch: 17, Batch: 300, Loss: 0.012338525179773569
# Epoch: 18, Batch: 100, Loss: 0.011193732071667909
# Epoch: 18, Batch: 200, Loss: 0.010817063890397549
# Epoch: 18, Batch: 300, Loss: 0.010683526135981083
# Epoch: 19, Batch: 100, Loss: 0.009407218255102634
# Epoch: 19, Batch: 200, Loss: 0.010244791470468044
# Epoch: 19, Batch: 300, Loss: 0.009743804126977921
# Epoch: 20, Batch: 100, Loss: 0.009252945758402348
# Epoch: 20, Batch: 200, Loss: 0.008709307640790939
# Epoch: 20, Batch: 300, Loss: 0.009342606864869594
# Epoch: 21, Batch: 100, Loss: 0.007963596023619174
# Epoch: 21, Batch: 200, Loss: 0.008554150808602572
# Epoch: 21, Batch: 300, Loss: 0.008426203325390815
# Epoch: 22, Batch: 100, Loss: 0.00737447077408433
# Epoch: 22, Batch: 200, Loss: 0.007412059588357806
# Epoch: 22, Batch: 300, Loss: 0.007668901374563575
# Epoch: 23, Batch: 100, Loss: 0.0067131954673677685
# Epoch: 23, Batch: 200, Loss: 0.006608049077913165
# Epoch: 23, Batch: 300, Loss: 0.006996384123340249
# Epoch: 24, Batch: 100, Loss: 0.006447509305551648
# Epoch: 24, Batch: 200, Loss: 0.005692814147099852
# Epoch: 24, Batch: 300, Loss: 0.006462765438482165
# Epoch: 25, Batch: 100, Loss: 0.005862993495538831
# Epoch: 25, Batch: 200, Loss: 0.006145559960976243
# Epoch: 25, Batch: 300, Loss: 0.006186541773378849
# Epoch: 26, Batch: 100, Loss: 0.005584091177210212
# Epoch: 26, Batch: 200, Loss: 0.005025620395317673
# Epoch: 26, Batch: 300, Loss: 0.005491619021631778
# Epoch: 27, Batch: 100, Loss: 0.005593868719413877
# Epoch: 27, Batch: 200, Loss: 0.0050019419491291045
# Epoch: 27, Batch: 300, Loss: 0.0051379510429687796
# Epoch: 28, Batch: 100, Loss: 0.004615859154844657
# Epoch: 28, Batch: 200, Loss: 0.004562794187571853
# Epoch: 28, Batch: 300, Loss: 0.0050849721794947985
# Epoch: 29, Batch: 100, Loss: 0.00428026680322364
# Epoch: 29, Batch: 200, Loss: 0.004379769037943334
# Epoch: 29, Batch: 300, Loss: 0.00508472341299057
# Epoch: 30, Batch: 100, Loss: 0.00423982656840235
# Epoch: 30, Batch: 200, Loss: 0.004117103572003543
# Epoch: 30, Batch: 300, Loss: 0.004332089841831475

# %% [markdown]
# ## 모델의 저장 및 로드

# %%
# 잘 학습된 모델인지 간단히 한 batch에 대해서 확인

dataiter = iter(test_loader)
images, labels = next(dataiter)

imshow(torchvision.utils.make_grid(images))
print(' '.join('\t{}'.format(class_list[labels[j]]) for j in range(4))) # batch-size = 4
# Out:
# 	cat 	ship 	ship 	car

# %%
# 저장

PATH = './cifar_net.pth'
torch.save(myNet.state_dict(), PATH)

# %%
# 불러오기

Loaded_Net = Net().to(device)
Loaded_Net.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## 모델 테스트
# * 조건
# > 전체 accuracy가 70% 이상이어야한다.<br>
# > 각각의 class에 대한 accuracy는 60% 이상이어야한다.

# %%
# 전체 accuracy 확인; 70% 이상 성능값

correct = 0
total = 0

with torch.no_grad():
    for data in test_loader:
        images, labels = data[0].to(device), data[1].to(device)      # model객체도 gpu에 저장했음으로, 사용되는 데이터도 gpu에 저장한다.; to(device) 사용
        outputs = myNet(images)                                      # y_pred                                                                       
        _, predicted = torch.max(outputs.data, axis=1)               # 확률이 가장 큰 것의 label을 최종 예측값으로 선택
        total += labels.size(0) # 전체 갯수
        correct += (predicted == labels).sum().item()                # 맞춘 갯수
    
    print(100 * correct / total)
# Out:
# 82.2

# %% [markdown]
# - 어떤 것을 잘 분류했고, 잘 못했는지 확인

# %%
# 각각의 class에 대한 accuracy 확인; 각각의 class에 대한 60% 이상 성능값

class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

with torch.no_grad():
    for data in test_loader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = Loaded_Net(images)
        _, predicted = torch.max(outputs.data, axis=1)
        c = (predicted == labels).squeeze()
        for i in range(4): # 각각의 batch(batch-size : 4) 마다 계싼
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(10):
    print("Accuracy of {}: {}%".format(class_list[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane: 78.78787878787878%
# Accuracy of car: 96.55172413793103%
# Accuracy of bird: 66.66666666666667%
# Accuracy of cat: 73.07692307692308%
# Accuracy of deer: 79.16666666666667%
# Accuracy of dog: 75.0%
# Accuracy of frog: 84.375%
# Accuracy of horse: 87.5%
# Accuracy of ship: 89.28571428571429%
# Accuracy of truck: 100.0%
