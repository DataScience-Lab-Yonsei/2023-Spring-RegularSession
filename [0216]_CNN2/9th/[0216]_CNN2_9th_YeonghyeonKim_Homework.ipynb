# %% [markdown]
# # 초기 세팅

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms

import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

# %%
# !pip install torchsummary
from torchsummary import summary

# %% [markdown]
# - 현재 GPU 설정

# %%
# colab의 runtime-type을 GPU로 설정해서, True가 나오도록 한다.

torch.cuda.is_available()
# Out:
# True

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')  # gpu('cuda')가 사용가능하면, gpu를 이용하도록 설정
device
# Out:
# device(type='cuda')

# %% [markdown]
# # CIFAR10 분류 모델
# * R/G/B(3) 이미지 데이터 분류
# * 32x32 pixel

# %% [markdown]
# ## 전처리 설정

# %%
# transform 정의

CIFAR_transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]) # r,g,b 데이터임으로, 3개의 인자값 전달

# %% [markdown]
# ## 데이터 로드 및 확인

# %%
# datasets

trainset = torchvision.datasets.CIFAR10(root = '/content', train = True, transform = CIFAR_transform, download = True)

testset = torchvision.datasets.CIFAR10(root = '/content', train = False, transform = CIFAR_transform, download = True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /content/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting /content/cifar-10-python.tar.gz to /content
# Files already downloaded and verified

# %%
# DataLoader

# batch-size = 4

train_loader = DataLoader(trainset, batch_size = 4, shuffle = True, num_workers=2)

test_loader = DataLoader(trainset, batch_size = 4, shuffle = False, num_workers=2)

# %%
# 숫자 label에 해당되는 값

class_list = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')

# %%
def imshow(img):
    img = img / 2 + 0.5
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1,2,0)))
    plt.show()

dataiter = iter(train_loader)
images, labels = next(dataiter)

imshow(torchvision.utils.make_grid(images))
print(' '.join('{}\t'.format(class_list[labels[j]]) for j in range(4)))
# Out:
# frog	 plane	 car	 frog

# %%
images.shape[0]
# Out:
# 4

# %% [markdown]
# ## 모델 생성

# %% [markdown]
# * input size = 4 * 3 * 32 * 32
# * output size = 4 * 10
# * 모델 조건
# > * convolution-layer : 2개 이상 사용
# > * maxpooling-layer : 1개 이상 사용
# > * fc-layer : 2개 이상 사용
# > * activation-function 으로 'relu' 사용

# %%
class Net(nn.Module):
    def __init__(self):
      super(Net, self).__init__()

      self.conv1 = nn.Conv2d(3, 16, 3, padding = 1)
      self.conv2 = nn.Conv2d(16, 16, 3, padding = 1)
      self.conv3 = nn.Conv2d(16, 32, 3, padding = 1)
      self.conv4 = nn.Conv2d(32, 32, 3, padding = 1)
      self.conv5 = nn.Conv2d(32, 64, 3, padding = 1)
      self.fc1 = nn.Linear(4096, 1000)
      self.fc2 = nn.Linear(1000, 10)

    def forward(self, x):
      x = F.relu(self.conv1(x))
      x = F.relu(self.conv2(x))
      x = F.max_pool2d(x, 2)
      x = F.relu(self.conv3(x))
      x = F.relu(self.conv4(x))
      x = F.max_pool2d(x, 2)
      x = F.relu(self.conv5(x))
      x = x.view(x.shape[0], -1)
      x = F.relu(self.fc1(x))
      x = self.fc2(x)

      return x

# %%
myNet = Net().to(device) # gpu에 모델 저장
myNet
# Out:
# Net(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=4096, out_features=1000, bias=True)
#   (fc2): Linear(in_features=1000, out_features=10, bias=True)
# )

# %%
# input; (4 * 3 * 32 * 32)

input = images.to(device)
input.size()
# Out:
# torch.Size([4, 3, 32, 32])

# %%
# output; (4 * 10)

output = myNet.forward(input)
output.size()
# Out:
# torch.Size([4, 10])

# %%
# 모델 구조 확인

summary(myNet, input_size=(3, 32, 32), batch_size=4)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [4, 16, 32, 32]             448
#             Conv2d-2            [4, 16, 32, 32]           2,320
#             Conv2d-3            [4, 32, 16, 16]           4,640
#             Conv2d-4            [4, 32, 16, 16]           9,248
#             Conv2d-5              [4, 64, 8, 8]          18,496
#             Linear-6                  [4, 1000]       4,097,000
#             Linear-7                    [4, 10]          10,010
# ================================================================
# Total params: 4,142,162
# Trainable params: 4,142,162
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.05
# Forward/backward pass size (MB): 1.66
# Params size (MB): 15.80
# Estimated Total Size (MB): 17.50
# ----------------------------------------------------------------

# %% [markdown]
# ## 손실함수와 옵티마이저

# %%
criterion = nn.CrossEntropyLoss() # 다중분류; CrossEntropyLoss
optimizer =  optim.SGD(myNet.parameters(), lr=0.001, momentum=0.9)# SGD; lr=0.001 & momentum=0.9

# %% [markdown]
# ## 모델 학습

# %%
# epochs = 10

for epoch in range(10):
    running_loss = 0.0

    for i, data in enumerate(train_loader, 0):
        inputs, labels = data[0].to(device), data[1].to(device)

        optimizer.zero_grad()                            # 가중치 초기화
        y_pred = myNet(inputs)                            # y_pred
        loss = criterion(y_pred, labels)                            # 손실함수를 이용해서 loss계산
        loss.backward()                            # back-propagation
        optimizer.step()                            # 가중치 업데이트

        running_loss += loss.item()
        if i % 2000 == 1999:
            print("Epoch: {}, Batch: {}, Loss: {}".format(epoch+1, i+1, running_loss/2000))
            running_loss = 0.0
# Out:
# Epoch: 1, Batch: 2000, Loss: 2.231400480389595
# Epoch: 1, Batch: 4000, Loss: 1.910573980987072
# Epoch: 1, Batch: 6000, Loss: 1.684405940771103
# Epoch: 1, Batch: 8000, Loss: 1.5408023377731443
# Epoch: 1, Batch: 10000, Loss: 1.433621074706316
# Epoch: 1, Batch: 12000, Loss: 1.345529733978212
# Epoch: 2, Batch: 2000, Loss: 1.232111985053867
# Epoch: 2, Batch: 4000, Loss: 1.1859498447440564
# Epoch: 2, Batch: 6000, Loss: 1.1299359494298697
# Epoch: 2, Batch: 8000, Loss: 1.0555011395961047
# Epoch: 2, Batch: 10000, Loss: 1.003692745317705
# Epoch: 2, Batch: 12000, Loss: 1.0012260865261777
# Epoch: 3, Batch: 2000, Loss: 0.8817743694814854
# Epoch: 3, Batch: 4000, Loss: 0.8451205387925729
# Epoch: 3, Batch: 6000, Loss: 0.8475225021438673
# Epoch: 3, Batch: 8000, Loss: 0.8444066909379326
# Epoch: 3, Batch: 10000, Loss: 0.7998562429693993
# Epoch: 3, Batch: 12000, Loss: 0.8041437374406378
# Epoch: 4, Batch: 2000, Loss: 0.6248947829729877
# Epoch: 4, Batch: 4000, Loss: 0.6212583327666799
# Epoch: 4, Batch: 6000, Loss: 0.6784265368591296
# Epoch: 4, Batch: 8000, Loss: 0.6449234300799508
# Epoch: 4, Batch: 10000, Loss: 0.640132732360922
# Epoch: 4, Batch: 12000, Loss: 0.6503494828432158
# Epoch: 5, Batch: 2000, Loss: 0.4107067147360212
# Epoch: 5, Batch: 4000, Loss: 0.44925276244161433
# Epoch: 5, Batch: 6000, Loss: 0.4631140171730985
# Epoch: 5, Batch: 8000, Loss: 0.4877981036654237
# Epoch: 5, Batch: 10000, Loss: 0.49473216333323583
# Epoch: 5, Batch: 12000, Loss: 0.49790019706763994
# Epoch: 6, Batch: 2000, Loss: 0.2632746255461434
# Epoch: 6, Batch: 4000, Loss: 0.28563509934730813
# Epoch: 6, Batch: 6000, Loss: 0.32433061502081534
# Epoch: 6, Batch: 8000, Loss: 0.33149203659203275
# Epoch: 6, Batch: 10000, Loss: 0.356399792781777
# Epoch: 6, Batch: 12000, Loss: 0.3817105476533252
# Epoch: 7, Batch: 2000, Loss: 0.18594676524281664
# Epoch: 7, Batch: 4000, Loss: 0.20655224725201762
# Epoch: 7, Batch: 6000, Loss: 0.2321536697794
# Epoch: 7, Batch: 8000, Loss: 0.26827827404679044
# Epoch: 7, Batch: 10000, Loss: 0.25829363605191374
# Epoch: 7, Batch: 12000, Loss: 0.2731080904261453
# Epoch: 8, Batch: 2000, Loss: 0.1302107072627176
# Epoch: 8, Batch: 4000, Loss: 0.15265630477134223
# Epoch: 8, Batch: 6000, Loss: 0.17629626519334926
# Epoch: 8, Batch: 8000, Loss: 0.18425715658883915
# Epoch: 8, Batch: 10000, Loss: 0.20317694376433246
# Epoch: 8, Batch: 12000, Loss: 0.22044748552249993
# Epoch: 9, Batch: 2000, Loss: 0.11869005193943566
# Epoch: 9, Batch: 4000, Loss: 0.14818838291802375
# Epoch: 9, Batch: 6000, Loss: 0.14192636979129145
# Epoch: 9, Batch: 8000, Loss: 0.16488381505696242
# Epoch: 9, Batch: 10000, Loss: 0.1731675797192734
# Epoch: 9, Batch: 12000, Loss: 0.18846867850003343
# Epoch: 10, Batch: 2000, Loss: 0.10634004577773044
# Epoch: 10, Batch: 4000, Loss: 0.11804981682369861
# Epoch: 10, Batch: 6000, Loss: 0.1207275139906673
# Epoch: 10, Batch: 8000, Loss: 0.13667301224055833
# Epoch: 10, Batch: 10000, Loss: 0.16258694176470123
# Epoch: 10, Batch: 12000, Loss: 0.1575924684463545

# %% [markdown]
# ## 모델의 저장 및 로드

# %%
# 잘 학습된 모델인지 간단히 한 batch에 대해서 확인

dataiter = iter(test_loader)
images, labels = next(dataiter)

imshow(torchvision.utils.make_grid(images))
print(' '.join('\t{}'.format(class_list[labels[j]]) for j in range(4))) # batch-size = 4
# Out:
# 	frog 	truck 	truck 	deer

# %%
# 저장

PATH = './cifar_net.pth'
torch.save(myNet.state_dict(), PATH)

# %%
# 불러오기

Loaded_Net = Net().to(device)
Loaded_Net.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## 모델 테스트
# * 조건
# > 전체 accuracy가 70% 이상이어야한다.<br>
# > 각각의 class에 대한 accuracy는 60% 이상이어야한다.

# %%
# 전체 accuracy 확인; 70% 이상 성능값

correct = 0
total = 0

with torch.no_grad():
    for data in test_loader:
        images, labels = data[0].to(device), data[1].to(device)                                              # model객체도 gpu에 저장했음으로, 사용되는 데이터도 gpu에 저장한다.; to(device) 사용
        outputs = myNet(images)                                              # y_pred
        _, predicted = torch.max(outputs.data, axis=1)  # 확률이 가장 큰 것의 label을 최종 예측값으로 선택
        total += labels.size(0) # 전체 갯수
        correct += (predicted == labels).sum().item()   # 맞춘 갯수
    
    print(100 * correct / total)
# Out:
# 97.49

# %% [markdown]
# - 어떤 것을 잘 분류했고, 잘 못했는지 확인

# %%
# 각각의 class에 대한 accuracy 확인; 각각의 class에 대한 60% 이상 성능값

class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

with torch.no_grad():
    for data in test_loader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = Loaded_Net(images)
        _, predicted = torch.max(outputs.data, axis=1)
        c = (predicted == labels).squeeze()
        for i in range(4): # 각각의 batch(batch-size : 4) 마다 계싼
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(10):
    print("Accuracy of {}: {}%".format(class_list[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane: 96.0%
# Accuracy of car: 98.26%
# Accuracy of bird: 97.9%
# Accuracy of cat: 96.48%
# Accuracy of deer: 96.28%
# Accuracy of dog: 97.36%
# Accuracy of frog: 97.9%
# Accuracy of horse: 97.84%
# Accuracy of ship: 97.72%
# Accuracy of truck: 99.16%
